# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
longevity_df = pd.read_csv('LiveLongerData.csv', sep=',')

# %%
print(longevity_df)
# Out:
#                                                Factor  Years gained / lost  \
# 0                                             Smoking               -10.00
# 1                                        Sitting Down                -3.00
# 2                                   Too much sleeping                -1.50
# 3                                       More Optimism                 2.00
# 4                                           More Pets                 3.00
# 5                    more professional responsibility                 3.50
# 6                                      Healthy Eating                 7.00
# 7                                            Red Meat                -1.00
# 8                               Alcohol (heavy abuse)               -11.00
# 9                                         City living                -2.50
# 10                                     Mental Illness               -25.00
# ...

# %%
longevity_df.head()
# Out:
#               Factor  Years gained / lost strength of science?  \
# 0            Smoking                -10.0               strong
# 1       Sitting Down                 -3.0           suggestive
# 2  Too much sleeping                 -1.5           suggestive
# 3      More Optimism                  2.0           suggestive
# 4          More Pets                  3.0                 good
#
#    strength of science as a number sexes affected    effect  \
# 0                                3           Both  negative
# 1                                1           Both  negative
# 2                                1           Both  negative
# 3                                1         Female  positive
# 4                                2           Both  positive
#
#                                              Comment  \
# 0  10 years gained (against those who continue to...
# 1                       for 8-11 hours sitting a day
# 2          7 hours ideal, no more than 8 hrs a night
# ...

# %%
longevty_columns = longevity_df.columns
print(longevty_columns) #Prints the name of the columns.
# Out:
# Index(['Factor', 'Years gained / lost', 'strength of science?',
#        'strength of science as a number', 'sexes affected', 'effect',
#        'Comment', 'Note', 'ID', 'Sources', 'Links'],
#       dtype='object')

# %%
longevity_df[['Factor']] #Here I printed the factors column to see what factors I am interested in and what I could do with them.
# Out:
#                                                Factor
# 0                                             Smoking
# 1                                        Sitting Down
# 2                                   Too much sleeping
# 3                                       More Optimism
# 4                                           More Pets
# 5                    more professional responsibility
# 6                                      Healthy Eating
# 7                                            Red Meat
# 8                               Alcohol (heavy abuse)
# 9                                         City living
# 10                                     Mental Illness
# 11                                            Obesity
# 12                              More Health Checks #2
# 13                            Living at high altitude
# 14                                      Good marriage
# 15                                          Less Food
# ...

# %%
longevity_df.hist() #The following grapth does is not helpul.
# Out:
# array([[<Axes: title={'center': 'Years gained / lost'}>,
#         <Axes: title={'center': 'strength of science as a number'}>],
#        [<Axes: title={'center': 'ID'}>, <Axes: >]], dtype=object)

# %%
longevity_df.iloc[19:]
# Out:
#                             Factor  Years gained / lost strength of science?  \
# 19  Spending more time with women                  15.0           suggestive
# 20                    Avoid Cancer                 15.0           suggestive
# 21                   More Exercise                  2.0               strong
# 22                A little alcohol                  2.0           suggestive
# 23     More conscientious & stable                  2.5           suggestive
# 24                         Orgasms                  4.0           suggestive
# 25                   A little wine                  5.0           suggestive
# 26                      More Money                  7.5                 good
# 27                   being a woman                  5.1                 good
# 28              More close Friends                  5.3           suggestive
# 29     Greater Faith (churchgoing)                  7.0           suggestive
# ...

# %% [markdown]
# Now I want to explore the data for the factor 'Spending more time with WOmen'

# %%
longevity_df.hist(x='Factor',y='Years gained/lost') # haha good try of me trying to plot this with categorical and numerical data. Let's try again below by looking at the pandas documentation.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\CODELearner1\iCloudDrive\CODE\Python\Pandas Homework - Life longevity Factors.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CODELearner1/iCloudDrive/CODE/Python/Pandas%20Homework%20-%20Life%20longevity%20Factors.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> longevity_df.hist(x='Factor',y='Years gained/lost')
#
# File c:\Users\CODELearner1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:247, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     160 """
#     161 Make a histogram of the DataFrame's columns.
#     162
#    (...)
#     244     >>> hist = df.hist(bins=3)
#     245 """
#     246 plot_backend = _get_plot_backend(backend)
# --> 247 return plot_backend.hist_frame(
# ...

# %%
fig, axs = plt.subplots()
axs.bar('Factor','Years gained / lost') #this only plotted the axes without data.
# Out:
# <BarContainer object of 1 artists>

# %%
factors_x = list(longevity_df.keys())
factors_y = longevity_df.values #here I don't need to use () because this returns NumPy aaray, it is not a funciton. 

#to Create a range of indices for the x-axis positions:
x_positions = range(len(factors_x))

#To create the bar chart:
fig, axs = plt.subplots()
axs.bar(x_positions, factors_y[:,0])

plt.show()
#trying to figure out how to plot the data in this graph
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\CODELearner1\iCloudDrive\CODE\Python\Pandas Homework - Life longevity Factors.ipynb Cell 12 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/CODELearner1/iCloudDrive/CODE/Python/Pandas%20Homework%20-%20Life%20longevity%20Factors.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> #To create the bar chart:
#       <a href='vscode-notebook-cell:/c%3A/Users/CODELearner1/iCloudDrive/CODE/Python/Pandas%20Homework%20-%20Life%20longevity%20Factors.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> fig, axs = plt.subplots()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CODELearner1/iCloudDrive/CODE/Python/Pandas%20Homework%20-%20Life%20longevity%20Factors.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a> axs.bar(x_positions, factors_y[:,0])
# ...
